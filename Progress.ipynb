# %%
import pandas as pd
from io import BytesIO
import requests
import random

def fetch_data(url, skiprows=0):
    r = requests.get(url)
    data = r.content

    return pd.read_csv(BytesIO(data), index_col=0, skiprows=skiprows)

catalog = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=0&format=csv", 2)

completed_sets = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=1791033131&format=csv")
completed_suppl = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=399306386&format=csv")

# %%
categories = catalog.keys()[7:]
repl_nan = { i : False for i in catalog.keys()[3:]}
repl_checked = { i : 'x' for i in catalog.keys()[3:]}

scrubbed_cat = catalog.fillna(value=repl_nan).replace(repl_checked, True)

# %%
categorical_cols = scrubbed_cat.columns[3:7]
ctotals = { col:scrubbed_cat[col].where(scrubbed_cat[col]==True).count() for col in categorical_cols }
ctotals
# Out:
# {'AR': 239, 'ALG': 216, 'DA': 116, 'GEO': 132}

# %%
skillset_cols = scrubbed_cat.columns[7:-4] 
stotals = { col:scrubbed_cat[col].where(scrubbed_cat[col]==True).count() for col in skillset_cols }
stotals
# Out:
# {'ARG': 29,
#  'FAD': 40,
#  'PCT': 55,
#  'NP': 45,
#  'DAP': 36,
#  'EAR': 41,
#  'EAF': 44,
#  'IAV': 44,
#  'FFS': 59,
#  'ROW': 30,
#  'RAT': 43,
#  'CT': 38,
#  'DST': 31,
#  'PROB': 47,
#  'PRS': 22,
#  'CC': 26,
#  'TRI': 43,
#  'CG': 24,
#  'MG': 18}

# %%
misc_cols = scrubbed_cat.columns[-4:]
mtotals = { col:scrubbed_cat[col].where(scrubbed_cat[col]==True).count() for col in misc_cols }
mtotals
# Out:
# {'WP': 42, '2WP': 25, 'VC': 20, 'AQ': 42}

# %%
completed_full = pd.concat([completed_sets, completed_suppl], ignore_index=False, sort=False).drop_duplicates().set_index('Global Id')
j = scrubbed_cat.join(completed_full, how='right', lsuffix='_left', rsuffix='_right', sort=False)
completed_meta = j[j['Local Id_right'].notna()]
completed_meta[50:100]
# Out:
#            Local Id_left Source Type     AR    ALG     DA    GEO    ARG  \
# Global Id
# 474                18.17      M   QC  False   True  False  False  False
# 480                18.23      M   QC  False   True  False  False  False
# 489                19.03      M   MC  False   True  False  False  False
# 503                19.17      M   MC  False   True  False  False  False
# 508                20.02      M   MA  False   True  False  False  False
# 511                20.05      M   NE  False   True  False  False  False
# 525                20.19      M   MC  False   True  False  False  False
# 538                20.32      M   MA  False   True  False  False  False
# 554                21.12      M   QC  False  False   True  False  False
# 568                21.26      M   NE  False  False   True  False  False
# 568                21.26      M   NE  False  False   True  False  False
# 578                21.36      M   NE  False  False   True  False  False
# 583                22.04      M   QC  False  False   True  False  False
# 601                22.22      M   QC  False  False   True  False  False
# 601                22.22      M   QC  False  False   True  False  False
# 604                22.25      M   QC  False  False   True  False  False
# 612                23.02      M   MC  False  False   True  False  False
# 637                23.27      M   MC  False  False   True  False  False
# 647                23.37      M   MC  False  False   True  False  False
# 663                25.07      M   NE  False  False  False   True  False
# 671                25.15      M   QC  False  False  False   True  False
# 672                25.16      M   QC  False  False  False   True  False
# 675                25.19      M   MC  False  False  False   True  False
# 696                26.18      M   QC  False  False  False   True  False
# 722                27.19      M   MC  False  False  False   True  False
# 737                27.34      M   MC  False  False  False   True  False
# 741                27.38      M   MC  False  False  False   True  False
# 756                28.11      M   MC  False  False  False   True  False
# 769                28.24      M   MC  False  False  False   True  False
# 777                29.08      M   NE  False  False  False   True  False
# 781                29.12      M   NE  False  False  False   True  False
# 790                30.03      M   QC   True  False  False  False  False
# 807                30.20      M   QC   True  False  False  False  False
# 817                30.30      M   QC   True  False  False  False  False
# 818                30.31      M   QC   True   True  False  False  False
# 829                30.42      M   QC  False   True  False  False  False
#
#              FAD    PCT  ...    TRI     CG     MG     WP    2WP     VC     AQ  \
# Global Id                ...
# 474        False  False  ...  False  False  False  False  False  False  False
# 480        False  False  ...  False  False  False  False  False  False  False
# 489        False  False  ...  False  False  False   True  False   True  False
# 503        False  False  ...  False  False  False  False  False   True  False
# 508        False  False  ...  False  False  False   True  False  False  False
# 511        False  False  ...  False  False  False  False  False  False  False
# 525        False  False  ...  False  False  False  False  False  False  False
# 538        False  False  ...  False  False  False  False  False  False  False
# 554        False  False  ...  False  False  False  False  False  False  False
# 568        False  False  ...  False  False  False  False  False  False  False
# 568        False  False  ...  False  False  False  False  False  False  False
# 578        False  False  ...  False  False  False  False  False  False  False
# 583        False  False  ...  False  False  False  False  False  False  False
# 601        False  False  ...  False  False  False  False  False  False  False
# 601        False  False  ...  False  False  False  False  False  False  False
# 604        False  False  ...  False  False  False  False  False  False  False
# 612        False  False  ...  False  False  False  False  False  False  False
# 637        False  False  ...  False  False  False  False  False  False  False
# 647        False  False  ...  False  False  False  False  False  False  False
# 663        False  False  ...  False  False  False  False  False  False  False
# 671        False  False  ...  False  False  False  False  False  False  False
# 672        False  False  ...  False  False  False  False  False  False  False
# 675        False  False  ...  False  False  False  False  False  False  False
# 696        False  False  ...  False  False  False  False  False  False  False
# 722        False  False  ...   True  False  False  False  False  False  False
# 737        False  False  ...   True  False  False  False  False  False  False
# 741        False  False  ...   True  False  False  False  False  False  False
# 756        False  False  ...  False   True  False  False  False  False  False
# 769        False  False  ...  False   True  False  False  False  False  False
# 777        False  False  ...  False  False   True  False  False  False  False
# 781        False  False  ...  False  False   True  False  False  False  False
# 790        False  False  ...  False  False  False  False  False  False   True
# 807        False  False  ...  False  False  False  False  False  False   True
# 817        False  False  ...  False  False  False  False  False  False   True
# 818        False  False  ...  False  False  False  False  False  False   True
# 829        False  False  ...  False  False  False  False  False  False   True
#
#           Local Id_right Completed Correct
# Global Id
# 474                18.17      True    True
# 480                18.23       NaN    True
# 489                19.03      True   False
# 503                20.05      True    True
# 508                20.02      True    True
# 511                21.12      True    True
# 525                20.19      True    True
# 538                20.32      True   False
# 554                21.26      True    True
# 568                25.16      True    True
# 568                22.22      True   False
# 578                21.36      True    True
# 583                22.04      True    True
# 601                28.11      True    True
# 601                26.05      True    True
# 604                22.25      True   False
# 612                23.02      True    True
# 637                23.27       NaN    True
# 647                23.37      True   False
# 663                25.07      True    True
# 671                25.15      True    True
# 672                28.24      True    True
# 675                25.19     False    True
# 696                26.18      True    True
# 722                27.19      True    True
# 737                27.34       NaN    True
# 741                27.38      True    True
# 756                28.11      True    True
# 769                29.08      True    True
# 777                29.18      True    True
# 781                29.12       NaN    True
# 790                30.03      True    True
# 807                30.20      True    True
# 817                30.30      True    True
# 818                30.31      True    True
# 829                30.42      True   False
#
# [36 rows x 33 columns]

# %%
def key_based_accuracy(completed_meta, keys):
    wrong = {}
    accuracy = {}
    for cat in keys:
        df = completed_meta[completed_meta[cat] == True]
        correct = df[df['Correct'] == True].count()[0]
        count = df.count()[0]

        wrong[cat] = df[df['Correct'] == False]
        accuracy[cat] = (count, correct / count)
        
    return (wrong, accuracy)

# %%
key_based_accuracy(completed_meta, categorical_cols)[1]
# Out:
# {'AR': (24, 0.8333333333333334),
#  'ALG': (33, 0.8787878787878788),
#  'DA': (12, 0.75),
#  'GEO': (12, 1.0)}

# %%
key_based_accuracy(completed_meta, skillset_cols)[1]
# Out:
# {'ARG': (2, 1.0),
#  'FAD': (5, 0.8),
#  'PCT': (4, 0.75),
#  'NP': (4, 0.75),
#  'DAP': (5, 0.8),
#  'EAR': (7, 0.8571428571428571),
#  'EAF': (10, 0.8),
#  'IAV': (8, 0.875),
#  'FFS': (7, 1.0),
#  'ROW': (3, 1.0),
#  'RAT': (6, 0.8333333333333334),
#  'CT': (5, 0.8),
#  'DST': (4, 0.75),
#  'PROB': (3, 0.6666666666666666),
#  'PRS': (4, 1.0),
#  'CC': (1, 1.0),
#  'TRI': (3, 1.0),
#  'CG': (2, 1.0),
#  'MG': (2, 1.0)}

# %%
key_based_accuracy(completed_meta, misc_cols)[1]
# Out:
# {'WP': (11, 0.8181818181818182),
#  '2WP': (4, 1.0),
#  'VC': (2, 0.5),
#  'AQ': (5, 0.8)}

# %%
def type_based_accuracy(completed_meta):
    accuracy = {}
    for typ in ['QC', 'MC', 'NE', 'MA']:
        df = completed_meta[completed_meta['Type'] == typ]
        correct = df[df['Correct'] == True].count()[0]
        count = df.count()[0]
        accuracy[typ] = (count, correct / count)
    return accuracy

# %%
type_based_accuracy(completed_meta)
# Out:
# {'QC': (27, 0.9259259259259259),
#  'MC': (32, 0.8125),
#  'NE': (17, 0.8823529411764706),
#  'MA': (2, 0.5)}
