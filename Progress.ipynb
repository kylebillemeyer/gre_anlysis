# %%
import pandas as pd
from io import BytesIO
import requests
import random

def fetch_data(url, skiprows=0):
    r = requests.get(url)
    data = r.content

    return pd.read_csv(BytesIO(data), index_col=0, skiprows=skiprows)

catalog = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=0&format=csv", 2)
data_interp_catalog = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=1340046923&format=csv", 0)

completed_sets = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=1791033131&format=csv")
completed_suppl = fetch_data("https://docs.google.com/spreadsheets/d/1JyGlqmLg9k7UubOw-V_CC8McRZxn2PtknvsrMIxvLGk/export?gid=399306386&format=csv")

# %%
categories = catalog.keys()[7:]
repl_nan = { i : False for i in catalog.keys()[3:]}
repl_checked = { i : 'x' for i in catalog.keys()[3:]}

scrubbed_cat = catalog.fillna(value=repl_nan).replace(repl_checked, True)
scrubbed_di = data_interp_catalog.fillna(value=repl_nan).replace(repl_checked, True)
scrubbed_all = pd.concat([scrubbed_di, scrubbed_cat], ignore_index=False, sort=False).drop_duplicates()
scrubbed_all
# Out:
#           Set Id  Local Id     Source Type     AR    ALG     DA    GEO    ARG  \
# Global Id
# 1              A     24.01          M   MC  False  False   True  False  False
# 2              A     24.02          M   MC  False  False   True  False  False
# 3              A     24.03          M   MC  False  False   True  False  False
# 4              A     24.04          M   MC  False  False   True  False  False
# 5              A     24.05          M   MC  False  False   True  False  False
# 6              B     24.06          M   MC  False  False   True  False  False
# 7              B     24.07          M   MC  False  False   True  False  False
# 8              B     24.08          M   MC  False  False   True  False  False
# 9              C     24.09          M   MC  False  False   True  False  False
# 10             C     24.10          M   MC  False  False   True  False  False
# 11             C     24.11          M   MC  False  False   True  False  False
# 12             C     24.12          M   MC  False  False   True  False  False
# 13             D     24.13          M   MC  False  False   True  False  False
# 14             D     24.14          M   MC  False  False   True  False  False
# 15             D     24.15          M   MC  False  False   True  False  False
# 16             D     24.16          M   MC  False  False   True  False  False
# 17             E     24.17          M   MC  False  False   True  False  False
# 18             E     24.18          M   MA  False  False   True  False  False
# 19             E     24.19          M   MA  False  False   True  False  False
# 20             F     24.20          M   MC  False  False   True  False  False
# 21             F     24.21          M   MC  False  False   True  False  False
# 22             F     24.22          M   MC  False  False   True  False  False
# 23             F     24.23          M   MC  False  False   True  False  False
# 24             G     24.24          M   MC  False  False   True  False  False
# 25             G     24.25          M   MC  False  False   True  False  False
# 26             G     24.26          M   MC  False  False   True  False  False
# 27             G     24.27          M   MC  False  False   True  False  False
# 28             H     24.28          M   MC  False  False   True  False  False
# 29             H     24.29          M   MC  False  False   True  False  False
# 30             H     24.30          M   MC  False  False   True  False  False
# ...          ...       ...        ...  ...    ...    ...    ...    ...    ...
# 820          NaN     30.33          M   QC  False  False  False  False  False
# 821          NaN     30.34          M   MC  False  False  False  False  False
# 822          NaN     30.35          M   MC  False  False  False  False  False
# 823          NaN     30.36          M   MC  False  False  False  False  False
# 824          NaN     30.37          M   MC  False  False  False  False  False
# 820        False  ...  False  False  False  False  False  False  False  False
# 821        False  ...  False  False  False  False  False  False  False  False
# 822        False  ...  False  False  False  False  False  False  False  False
# 823        False  ...  False  False  False  False  False  False  False  False
# 824        False  ...  False  False  False  False  False  False  False  False
# 825        False  ...  False  False  False  False  False  False  False  False
# 826        False  ...  False  False  False  False  False  False  False  False
# 827        False  ...  False  False  False  False  False  False  False  False
# 828        False  ...  False  False  False  False  False  False  False  False
# 829        False  ...  False  False  False  False  False  False  False  False
# 830        False  ...   True  False  False  False  False   True  False  False
# 831        False  ...  False  False  False  False  False  False  False  False
# 832        False  ...  False  False  False  False  False  False  False  False
# 833        False  ...  False  False  False  False  False  False  False  False
# 834        False  ...  False   True  False  False  False  False  False  False
# 835         True  ...  False  False  False  False  False  False  False  False
# 836        False  ...  False  False  False  False  False  False  False  False
# 837        False  ...  False  False  False  False  False  False  False  False
# 838        False  ...  False  False  False  False  False  False  False  False
# 839        False  ...  False  False  False  False  False  False  False  False
# 840        False  ...  False  False  False  False  False   True  False  False
# 841        False  ...  False  False  False  False  False  False  False  False
# 842        False  ...   True   True  False  False   True  False  False  False
# 843        False  ...  False  False  False  False  False  False  False  False
# 844        False  ...  False  False  False  False  False  False  False  False
# 845        False  ...  False  False  False  False  False  False  False  False
# 846        False  ...  False  False   True  False  False  False  False  False
# 847        False  ...  False  False  False  False  False  False  False  False
# 848        False  ...  False  False  False  False  False  False  False  False
# 849        False  ...  False  False  False  False  False  False  False  False
#
#               AQ     DI
# Global Id
# 1          False   True
# 2          False   True
# 3          False   True
# 4          False   True
# 5          False   True
# 6          False   True
# 7          False   True
# 8          False   True
# 9          False   True
# 10         False   True
# 11         False   True
# 12         False   True
# 13         False   True
# 14         False   True
# 15         False   True
# 16         False   True
# 17         False   True
# 18         False   True
# 19         False   True
# 20         False   True
# 21         False   True
# 22         False   True
# 23         False   True
# 24         False   True
# 25         False   True
# 26         False   True
# 27         False   True
# 28         False   True
# 29         False   True
# 30         False   True
# ...          ...    ...
# 820         True  False
# 821         True  False
# 822         True  False
# 823         True  False
# 824         True  False
# 825         True  False
# 826         True  False
# 827         True  False
# 828         True  False
# 829         True  False
# 830        False  False
# 831        False  False
# 832        False  False
# 833        False  False
# 834        False  False
# 835        False  False
# 836        False  False
# 837        False  False
# 838        False  False
# 839        False  False
# 840        False  False
# 841        False  False
# 842        False  False
# 843        False   True
# 844        False   True
# 845        False   True
# 846        False  False
# 847        False  False
# 848        False  False
# 849        False  False
#
# [849 rows x 32 columns]

# %%
categorical_cols = scrubbed_all.columns[4:8]
ctotals = { col:scrubbed_all[col].where(scrubbed_all[col]==True).count() for col in categorical_cols }
ctotals
# Out:
# {'AR': 247, 'ALG': 223, 'DA': 166, 'GEO': 136}

# %%
skillset_cols = scrubbed_all.columns[8:-5] 
stotals = { col:scrubbed_all[col].where(scrubbed_all[col]==True).count() for col in skillset_cols }
stotals
skillset_cols
# Out:
# Index(['ARG', 'FAD', 'PCT', 'NP', 'DAP', 'EAR', 'EAF', 'IAV', 'FFS', 'ROW',
#        'RAT', 'CT', 'DST', 'PROB', 'PRS', 'CC', 'TRI', 'CG', 'MG'],
#       dtype='object')

# %%
misc_cols = scrubbed_all.columns[-5:]
mtotals = { col:scrubbed_all[col].where(scrubbed_all[col]==True).count() for col in misc_cols }
mtotals
# Out:
# {'WP': 45, '2WP': 25, 'VC': 20, 'AQ': 42, 'DI': 52}

# %%
completed_full = pd.concat([completed_sets, completed_suppl], ignore_index=False, sort=False).drop_duplicates()
j = scrubbed_all.join(completed_full, how='right', lsuffix='_left', rsuffix='_right', sort=False)
completed_meta = j[j['Local Id_right'].notna()]
completed_meta
# Out:
#           Set Id_left  Local Id_left     Source Type     AR    ALG     DA  \
# Global Id
# 1                   A          24.01          M   MC  False  False   True
# 2                   A          24.02          M   MC  False  False   True
# 3                   A          24.03          M   MC  False  False   True
# 5                   A          24.05          M   MC  False  False   True
# 42                  L          24.42          M   MC  False  False   True
# 43                  L          24.43          M   MC  False  False   True
# 44                  L          24.44          M   MC  False  False   True
# 45                  L          24.45          M   MC  False  False   True
# 58                NaN           7.09          M   NE   True  False  False
# 59                NaN           7.10          M   NE   True  False  False
# 61                NaN           7.12          M   QC   True  False  False
# 80                NaN           8.03          M   NE  False   True  False
# 92                NaN           8.15          M   QC  False   True  False
# 103               NaN           8.26          M   QC  False   True  False
# 104               NaN           8.27          M   MC   True   True  False
# 111               NaN           8.34          M   MA  False   True  False
# 117               NaN           9.05          M   MC  False   True  False
# 120               NaN           9.08          M   MC  False   True  False
# 123               NaN           9.11          M   QC  False   True  False
# 126               NaN           9.14          M   MC  False   True  False
# 127               NaN           9.15          M   QC  False   True  False
# 129               NaN           9.17          M   QC  False   True  False
# 131               NaN           9.19          M   QC  False   True  False
# 132               NaN           9.20          M   QC  False   True  False
# 140               NaN           9.28          M   QC   True   True  False
# 142               NaN           9.30          M   MC  False   True   True
# 144               NaN           9.32          M   MA  False   True  False
# 145               NaN           9.33          M   MA  False   True  False
# 155               NaN          10.02          M   MC  False   True  False
# 163               NaN          10.10          M   NE  False   True  False
# ...               ...            ...        ...  ...    ...    ...    ...
# 777               NaN          29.08          M   NE  False  False  False
# 781               NaN          29.12          M   NE  False  False  False
# 782               NaN          29.13          M   QC  False  False  False
# 784               NaN          29.15          M   QC  False  False  False
# 787               NaN          29.18          M   MC  False  False  False
# 790               NaN          30.03          M   QC   True  False  False
# 807               NaN          30.20          M   QC   True  False  False
# 817               NaN          30.30          M   QC   True  False  False
# 818               NaN          30.31          M   QC   True   True  False
# 829               NaN          30.42          M   QC  False   True  False
# 830               NaN           2.01  Man CAT 5   QC  False  False  False
# 831               NaN           2.02  Man CAT 5   QC   True  False  False
# 832               NaN           2.03  Man CAT 5   QC   True  False  False
# 833               NaN           2.04  Man CAT 5   QC  False   True  False
# 834               NaN           2.05  Man CAT 5   QC  False  False  False
# 835               NaN           2.06  Man CAT 5   QC   True  False  False
# 836               NaN           2.07  Man CAT 5   QC   True  False  False
# 837               NaN           2.08  Man CAT 5   MC   True  False  False
# 838               NaN           2.09  Man CAT 5   MA   True  False  False
# 839               NaN           2.10  Man CAT 5   NE  False   True  False
# 840               NaN           2.11  Man CAT 5   MC  False   True  False
# 841               NaN           2.12  Man CAT 5   MC  False   True  False
# 842               NaN           2.13  Man CAT 5   MC  False  False  False
# 843               NaN           2.14  Man CAT 5   MC  False   True  False
# 844        False  False  False  ...  False  False  False   True           9.0
# 845        False  False  False  ...  False  False  False   True           9.0
# 846         True  False  False  ...  False  False  False  False           9.0
# 847        False  False  False  ...  False  False  False  False           9.0
# 848        False  False  False  ...  False  False  False  False           9.0
# 849        False  False  False  ...  False  False  False  False           9.0
#
#            Local Id_right  Completed  Correct       Date  Unnamed: 4
# Global Id
# 1                   24.01       True     True        NaN         NaN
# 2                   24.02       True     True        NaN         NaN
# 3                   24.03       True     True        NaN         NaN
# 5                   24.05       True     True        NaN         NaN
# 42                  24.42       True     True        NaN         NaN
# 43                  24.43       True     True        NaN         NaN
# 44                  24.44       True     True        NaN         NaN
# 45                  24.45       True     True        NaN         NaN
# 58                   7.09       True     True        NaN         NaN
# 59                   7.10       True     True        NaN         NaN
# 61                   7.12        NaN     True        NaN         NaN
# 80                   8.03        NaN     True        NaN         NaN
# 92                   8.15        NaN     True        NaN         NaN
# 103                  8.26       True     True        NaN         NaN
# 104                  8.27        NaN     True        NaN        hard
# 111                  8.34        NaN     True        NaN    hard-ish
# 117                  9.05       True    False        NaN         NaN
# 120                  9.08        NaN     True        NaN         NaN
# 123                  9.11       True     True        NaN         NaN
# 126                  9.14       True     True        NaN         NaN
# 127                  9.15       True     True        NaN         NaN
# 129                  9.17       True     True        NaN         NaN
# 131                  9.19       True     True        NaN         NaN
# 132                  9.20        NaN     True        NaN        hard
# 140                  9.28       True     True        NaN         NaN
# 142                  9.30       True     True        NaN         NaN
# 144                  9.32        NaN    False        NaN         NaN
# 145                  9.33        NaN      NaN        NaN         NaN
# 155                 10.02       True     True        NaN         NaN
# 163                 10.10       True     True        NaN         NaN
# ...                   ...        ...      ...        ...         ...
# 777                 29.18       True     True        NaN         NaN
# 781                 29.12        NaN     True  8/29/2019         NaN
# 782                 29.13        NaN     True        NaN         NaN
# 784                 29.15        NaN    False        NaN         NaN
# 787                 29.18        NaN     True        NaN         NaN
# 790                 30.03       True     True        NaN         NaN
# 807                 30.20       True     True        NaN         NaN
# 817                 30.30       True     True        NaN         NaN
# 818                 30.31       True     True        NaN         NaN
# 829                 30.42       True    False        NaN         NaN
# 830                  1.01       True    False        NaN         NaN
# 831                  1.02       True    False        NaN         NaN
# 832                  1.03       True     True        NaN         NaN
# 833                  1.04       True    False        NaN         NaN
# 834                  1.05       True    False        NaN         NaN
# 835                  1.06       True     True        NaN         NaN
# 836                  1.07       True     True        NaN         NaN
# 837                  1.08       True    False        NaN         NaN
# 838                  1.09       True     True        NaN         NaN
# 839                  1.10       True     True        NaN         NaN
# 840                  1.11       True     True        NaN         NaN
# 841                  1.12       True    False        NaN         NaN
# 842                  1.13       True     True        NaN         NaN
# 843                  1.14       True     True        NaN         NaN
# 844                  1.15       True    False        NaN         NaN
# 845                  1.16       True     True        NaN         NaN
# 846                  1.17       True    False        NaN         NaN
# 847                  1.18       True    False        NaN         NaN
# 848                  1.19       True    False        NaN         NaN
# 849                  1.20       True     True        NaN         NaN
#
# [156 rows x 38 columns]

# %%
def key_based_accuracy(completed_meta, keys):
    wrong = {}
    accuracy = {}
    for cat in keys:
        df = completed_meta[completed_meta[cat] == True]
        correct = df[df['Correct'] == True].count()[cat]
        count = df.count()[cat]

        wrong[cat] = df[df['Correct'] == False]
        accuracy[cat] = (count, correct / count)
        
    return (wrong, accuracy)

# %%
cacc = key_based_accuracy(completed_meta, categorical_cols)[1]
cacc
# Out:
# {'AR': (46, 0.8260869565217391),
#  'ALG': (54, 0.7777777777777778),
#  'DA': (27, 0.7777777777777778),
#  'GEO': (31, 0.7096774193548387)}

# %%
sacc = key_based_accuracy(completed_meta, skillset_cols)[1]
sacc
# Out:
# {'ARG': (3, 1.0),
#  'FAD': (6, 0.8333333333333334),
#  'PCT': (11, 0.8181818181818182),
#  'NP': (11, 0.8181818181818182),
#  'DAP': (6, 0.6666666666666666),
#  'EAR': (12, 0.8333333333333334),
#  'EAF': (16, 0.8125),
#  'IAV': (13, 0.7692307692307693),
#  'FFS': (9, 0.7777777777777778),
#  'ROW': (7, 0.8571428571428571),
#  'RAT': (11, 0.7272727272727273),
#  'CT': (6, 0.6666666666666666),
#  'DST': (4, 0.75),
#  'PROB': (10, 0.6),
#  'PRS': (6, 0.8333333333333334),
#  'CC': (7, 0.5714285714285714),
#  'TRI': (6, 0.5),
#  'CG': (5, 1.0),
#  'MG': (8, 0.875)}

# %%
macc = key_based_accuracy(completed_meta, misc_cols)[1]
macc
# Out:
# {'WP': (19, 0.7894736842105263),
#  '2WP': (4, 1.0),
#  'VC': (2, 0.5),
#  'AQ': (5, 0.8),
#  'DI': (11, 0.9090909090909091)}

# %%
def type_based_accuracy(completed_meta):
    accuracy = {}
    for typ in ['QC', 'MC', 'NE', 'MA']:
        df = completed_meta[completed_meta['Type'] == typ]
        correct = df[df['Correct'] == True].count()['Type']
        count = df.count()['Type']
        accuracy[typ] = (count, correct / count)
    return accuracy

# %%
tacc = type_based_accuracy(completed_meta)
tacc
# Out:
# {'QC': (52, 0.7692307692307693),
#  'MC': (67, 0.8208955223880597),
#  'NE': (28, 0.8214285714285714),
#  'MA': (9, 0.4444444444444444)}

# %%
# Hardcoded from http://localhost:8888/notebooks/Documents/git/gre_analysis/Test%20Structure%20Analysis.ipynb.
# Recopy if data is added.

type_test_weights = {
    'MA': 0.0875, 
    'MC': 0.44000000000000006, 
    'NE': 0.095, 
    'QC': 0.3775
}

cat_test_weights = {
    'AR': (63, 0.37058823529411766),
    'ALG': (62, 0.36470588235294116),
    'DA': (43, 0.2529411764705882),
    'GEO': (35, 0.20588235294117646)
}

skillset_test_weights = {
    'ARG': (9, 0.052941176470588235),
     'FAD': (4, 0.023529411764705882),
     'PCT': (23, 0.13529411764705881),
     'NP': (13, 0.07647058823529412),
     'DAP': (7, 0.041176470588235294),
     'EAR': (10, 0.058823529411764705),
     'EAF': (27, 0.1588235294117647),
     'IAV': (13, 0.07647058823529412),
     'FFS': (8, 0.047058823529411764),
     'ROW': (7, 0.041176470588235294),
     'RAT': (11, 0.06470588235294118),
     'CT': (7, 0.041176470588235294),
     'DST': (4, 0.023529411764705882),
     'PROB': (11, 0.06470588235294118),
     'PRS': (5, 0.029411764705882353),
     'CC': (6, 0.03529411764705882),
     'TRI': (13, 0.07647058823529412),
     'CG': (9, 0.052941176470588235),
     'MG': (4, 0.023529411764705882)
}

misc_test_weights = {
    'WP': (15, 0.08823529411764706),
    '2WP': (5, 0.029411764705882353),
    'VC': (2, 0.011764705882352941),
    'AQ': (0, 0.0),
    'DI': (26, 0.15294117647058825)
}

# %%
# Note these values are psuedo-weighted. Questions can have multiple categories, so the weights won't add up to 1.
# The absolute values of each category are meaningless, but they are proportionate to the error rate and likelihood of 
# seeing the category on a test, thus providing some semblence of relative importance.
def weighted_accuracy(accuracy, test_weight):
    new_dict = {}
    for k in accuracy:
        new_dict[k] = (1-accuracy[k][1]) * test_weight[k][1]
    return new_dict

def weighted_sample_size(accuracy, test_weight):
    new_dict = {}
    for k in accuracy:
        new_dict[k] = test_weight[k][1] / accuracy[k][0]
    return new_dict

# %%
cweighted = weighted_accuracy(cacc, cat_test_weights)
sweighted = weighted_accuracy(sacc, skillset_test_weights)
mweighted = weighted_accuracy(macc, misc_test_weights)
sorted(list(cweighted.items()), key=lambda tup: tup[1], reverse=True)
sorted(list(sweighted.items()), key=lambda tup: tup[1], reverse=True)
sorted(list(mweighted.items()), key=lambda tup: tup[1], reverse=True)
sorted(list(sweighted.items()) + list(mweighted.items()), key=lambda tup: tup[1], reverse=True)
# Out:
# [('TRI', 0.03823529411764706),
#  ('EAF', 0.02977941176470588),
#  ('PROB', 0.025882352941176474),
#  ('PCT', 0.024598930481283414),
#  ('WP', 0.018575851393188854),
#  ('IAV', 0.01764705882352941),
#  ('RAT', 0.01764705882352941),
#  ('CC', 0.015126050420168069),
#  ('DI', 0.013903743315508027),
#  ('NP', 0.013903743315508019),
#  ('DAP', 0.013725490196078433),
#  ('CT', 0.013725490196078433),
#  ('FFS', 0.01045751633986928),
#  ('EAR', 0.009803921568627449),
#  ('ROW', 0.005882352941176472),
#  ('DST', 0.0058823529411764705),
#  ('VC', 0.0058823529411764705),
#  ('PRS', 0.0049019607843137246),
#  ('FAD', 0.0039215686274509795),
#  ('MG', 0.0029411764705882353),
#  ('ARG', 0.0),
#  ('CG', 0.0),
#  ('2WP', 0.0),
#  ('AQ', 0.0)]

# %%
sorted(list(cacc.items()), key=lambda tup: tup[1][0])
sorted(list(sacc.items()), key=lambda tup: tup[1][0])
sorted(list(sacc.items()) + list(macc.items()), key=lambda tup: tup[1][0])
# Out:
# [('VC', (2, 0.5)),
#  ('ARG', (3, 1.0)),
#  ('DST', (4, 0.75)),
#  ('2WP', (4, 1.0)),
#  ('CG', (5, 1.0)),
#  ('AQ', (5, 0.8)),
#  ('FAD', (6, 0.8333333333333334)),
#  ('DAP', (6, 0.6666666666666666)),
#  ('CT', (6, 0.6666666666666666)),
#  ('PRS', (6, 0.8333333333333334)),
#  ('TRI', (6, 0.5)),
#  ('ROW', (7, 0.8571428571428571)),
#  ('CC', (7, 0.5714285714285714)),
#  ('MG', (8, 0.875)),
#  ('FFS', (9, 0.7777777777777778)),
#  ('PROB', (10, 0.6)),
#  ('PCT', (11, 0.8181818181818182)),
#  ('NP', (11, 0.8181818181818182)),
#  ('RAT', (11, 0.7272727272727273)),
#  ('DI', (11, 0.9090909090909091)),
#  ('EAR', (12, 0.8333333333333334)),
#  ('IAV', (13, 0.7692307692307693)),
#  ('EAF', (16, 0.8125)),
#  ('WP', (19, 0.7894736842105263))]

# %%
sum(map(lambda x: x[1][0], sacc.items()))
# Out:
# 157
